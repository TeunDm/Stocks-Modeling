# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing  # or whichever part of sklearn you need
import scipy

# %%
from library import loading_data
data = loading_data()
data.head()
# Out:
#                         Date      Open      High       Low     Close  \
# 0  1999-01-22 00:00:00-05:00  0.040129  0.044786  0.035590  0.037621
# 1  1999-01-25 00:00:00-05:00  0.040607  0.042039  0.037621  0.041562
# 2  1999-01-26 00:00:00-05:00  0.042039  0.042876  0.037740  0.038337
# 3  1999-01-27 00:00:00-05:00  0.038457  0.039412  0.036307  0.038218
# 4  1999-01-28 00:00:00-05:00  0.038218  0.038457  0.037859  0.038098
#
#        Volume  Dividends  Stock Splits
# 0  2714688000        0.0           0.0
# 1   510480000        0.0           0.0
# 2   343200000        0.0           0.0
# 3   244368000        0.0           0.0
# 4   227520000        0.0           0.0

# %%
#check the range    
print(data['Date'].iloc[1], data['Date'].iloc[-1])
print(data.describe())
data.shape
# Out:
# 1999-01-25 00:00:00-05:00 2024-08-28 00:00:00-04:00
#               Open         High          Low        Close        Volume  \
# count  6442.000000  6442.000000  6442.000000  6442.000000  6.442000e+03
# mean      6.540460     6.662964     6.408289     6.542479  6.052807e+08
# std      17.305249    17.635883    16.923466    17.299911  4.318950e+08
# min       0.032008     0.032605     0.030574     0.031291  1.968000e+07
# 25%       0.254877     0.262747     0.247919     0.254380  3.449130e+08
# 50%       0.428842     0.435835     0.421907     0.429071  5.064340e+08
# 75%       4.192872     4.252301     4.133276     4.190607  7.355910e+08
# max     139.800003   140.759995   132.419998   135.580002  9.230856e+09
#
#          Dividends  Stock Splits
# count  6442.000000   6442.000000
# mean      0.000025      0.003337
# std       0.000315      0.142165
# min       0.000000      0.000000
# 25%       0.000000      0.000000
# 50%       0.000000      0.000000
# ...

# %%
#lets plot the distribution of all variables
from library import plot_dist
plot_dist(data)

# %%
#plot the end of day prices
plt.figure(figsize=(12, 6))
plt.plot(data['Date'], data['Close'], label='Close Price')
plt.title('End of Day Close Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.grid()
plt.show()
